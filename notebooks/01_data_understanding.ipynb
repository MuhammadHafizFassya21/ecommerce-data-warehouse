# %%
import pandas as pd
from pathlib import Path

RAW_DATA = Path("../data/raw")

files = {
    "customers": "olist_customers_dataset.csv",
    "geolocation": "olist_geolocation_dataset.csv",
    "order_items": "olist_order_items_dataset.csv",
    "order_payments": "olist_order_payments_dataset.csv",
    "order_reviews": "olist_order_reviews_dataset.csv",
    "orders": "olist_orders_dataset.csv",
    "products": "olist_products_dataset.csv",
    "sellers": "olist_sellers_dataset.csv",
    "category_translation": "product_category_name_translation.csv"
}

dataframes ={}


for name, file in files.items():
    file_path = RAW_DATA_PATH / file
    dataframes[name] = pd.read_csv(file_path)
    print(f"{name}: {dataframes[name].shape}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 22
#      18 dataframes ={}
#      19
#      20
#      21 for name, file in files.items():
# ---> 22     file_path = RAW_DATA_PATH / file
#      23     dataframes[name] = pd.read_csv(file_path)
#      24     print(f"{name}: {dataframes[name].shape}")
#
# NameError: name 'RAW_DATA_PATH' is not defined

# %%
for name, df in dataframes.items():
    print("=" * 50)
    print(f"Dataset: {name}")
    print("=" * 50)
    print(df.info())
    print("\nMissing Values:")
    print(df.isnull().sum())
    print("\nDuplicate Rows:")
    print(df.duplicated().sum())
    print("\nSample Data:")
    display(df.head())
